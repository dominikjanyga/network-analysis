# %% [markdown]
# <a href="https://colab.research.google.com/github/dominikjanyga/network-analysis/blob/main/2_network_analysis_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Data cleaning.
# Part two of the network analysis is intended for preparing and transforming the data collected from the first part

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_shareholder = pd.read_csv("/content/drive/MyDrive/Projects/network-analysis/shareholder_data_15102024")
df_officers = pd.read_csv("/content/drive/MyDrive/Projects/network-analysis/company_officers_28102024")
df_financials = pd.read_csv("/content/drive/MyDrive/Projects/network-analysis/company_financials_28102024")

# %% [markdown]
# # Company officers data

# %%
df_officers
# Out:
#                         officer_name  \
# 0          Mr. Miroslaw  Janisiewicz
# 1       Mr. Przemyslaw Piotr Marszal
# 2           Mr. Grzegorz  Miechowski
# 3     Mr. Michal Wojciech Drozdowski
# 4                 Mr. Pawel  Feldman
# ...                              ...
# 1592              Mr. Wieslaw  Nowak
# 1593          Mr. Marcin  Wisniewski
# 1594               Mr. Maciej  Nowak
# 1595            Mr. Jerzy  Czeremuga
# 1596               Ms. Anna  Mroczek
#
#                                           officer_title  ticker
# 0                     President of the Management Board  06N.WA
# 1                     President of the Management Board  11B.WA
# 2                            Member of Management Board  11B.WA
# 3                        Member of the Management Board  11B.WA
# 4                        Member of the Management Board  11B.WA
# ...                                                 ...     ...
# 1592            President of the Management Board & CEO  ZUE.WA
# 1593  Vice President of the Management Board & Direc...  ZUE.WA
# 1594  Vice President of Management Board and Legal &...  ZUE.WA
# 1595  Vice President of the Management Board & Direc...  ZUE.WA
# 1596  Vice-President of Management Board & Financial...  ZUE.WA
#
# [1597 rows x 3 columns]

# %%
df_officers.groupby(['officer_name']).size().sort_values(ascending=False).head()
# Out:
# officer_name
# Ms. Malgorzata  Patrowicz      3
# Mr. Tomasz Krzysztof Rogala    2
# Mr. Piotr  Bielinski           2
# Mr. Jacek  Szymanek            2
# Mr. Pawel  Szataniak           2
# dtype: int64

# %% [markdown]
# # Cleaning shareholder data

# %%
df_shareholder
# Out:
#        Lp               Akcjonariusz Udział w kapitale  Liczba akcji  \
# 0     1.0      RG Ventures Sp. z o.o            24.46%     3405807.0
# 1     1.0        Grzegorz Miechowski             6.97%      168413.0
# 2     2.0            TFI Esaliens SA             6.51%      157257.0
# 3     3.0  OFE Nationale-Nederlanden             5.69%      137648.0
# 4     4.0         Przemysław Marszał             4.96%      120003.0
# ...   ...                        ...               ...           ...
# 3655  3.0               OFE Generali             6.35%     1461659.0
# 3656  4.0                     ZUE SA             1.15%      264652.0
# 3657  5.0         TFI BNP Paribas SA             0.77%      177171.0
# 3658  6.0                    DFE PKO             0.22%       49763.0
# 3659  7.0                 TFI PKO SA             0.16%       37294.0
#
#       Ostatnia zmiana Wartość rynkowa (PLN) Udział na WZA  Liczba głosów  \
# 0                 0.0              10.4 mln        24.46%      3405807.0
# 1                 0.0              47.4 mln         6.97%       168413.0
# 2            -13027.0              44.3 mln         6.51%       157257.0
# 3                 0.0              38.8 mln         5.69%       137648.0
# 4                 0.0              33.8 mln         4.96%       120003.0
# ...               ...                   ...           ...            ...
# 3655              0.0              13.2 mln         6.35%      1461659.0
# 3656              0.0              2.39 mln         0.00%            0.0
# 3657         117040.0              1.60 mln         0.77%       177171.0
# 3658          22184.0               450 tys         0.22%        49763.0
# 3659              0.0               337 tys         0.16%        37294.0
#
#       Ostatnia zmiana.1 Data aktualizacji ticker
# 0                   0.0       26 wrz 2024    06N
# 1                   0.0       27 sie 2024    11B
# 2              -13027.0       28 cze 2024    11B
# 3                   0.0       29 gru 2023    11B
# 4                   0.0        6 cze 2024    11B
# ...                 ...               ...    ...
# 3655                0.0        7 cze 2024    ZUE
# 3656                0.0       28 cze 2017    ZUE
# 3657           117040.0       28 cze 2024    ZUE
# 3658            22184.0       29 gru 2023    ZUE
# 3659                0.0       28 cze 2024    ZUE
#
# [3660 rows x 11 columns]

# %%
df_shareholder = df_shareholder.drop(df_shareholder.columns[[0, 4, 6, 7, 8, 9]], axis=1)
df_shareholder
# Out:
#                    Akcjonariusz Udział w kapitale  Liczba akcji  \
# 0         RG Ventures Sp. z o.o            24.46%     3405807.0
# 1           Grzegorz Miechowski             6.97%      168413.0
# 2               TFI Esaliens SA             6.51%      157257.0
# 3     OFE Nationale-Nederlanden             5.69%      137648.0
# 4            Przemysław Marszał             4.96%      120003.0
# ...                         ...               ...           ...
# 3655               OFE Generali             6.35%     1461659.0
# 3656                     ZUE SA             1.15%      264652.0
# 3657         TFI BNP Paribas SA             0.77%      177171.0
# 3658                    DFE PKO             0.22%       49763.0
# 3659                 TFI PKO SA             0.16%       37294.0
#
#      Wartość rynkowa (PLN) ticker
# 0                 10.4 mln    06N
# 1                 47.4 mln    11B
# 2                 44.3 mln    11B
# 3                 38.8 mln    11B
# 4                 33.8 mln    11B
# ...                    ...    ...
# 3655              13.2 mln    ZUE
# 3656              2.39 mln    ZUE
# 3657              1.60 mln    ZUE
# 3658               450 tys    ZUE
# 3659               337 tys    ZUE
#
# [3660 rows x 5 columns]

# %%
df_shareholder = df_shareholder.rename(columns={
    "Akcjonariusz":"Shareholder",
    "Udział w kapitale":"Ownership_%",
    "Liczba akcji": "Number_of_shares",
    "Wartość rynkowa (PLN)":"Market_value",
})
df_shareholder
# Out:
#                     Shareholder Ownership_%  Number_of_shares Market_value  \
# 0         RG Ventures Sp. z o.o      24.46%         3405807.0     10.4 mln
# 1           Grzegorz Miechowski       6.97%          168413.0     47.4 mln
# 2               TFI Esaliens SA       6.51%          157257.0     44.3 mln
# 3     OFE Nationale-Nederlanden       5.69%          137648.0     38.8 mln
# 4            Przemysław Marszał       4.96%          120003.0     33.8 mln
# ...                         ...         ...               ...          ...
# 3655               OFE Generali       6.35%         1461659.0     13.2 mln
# 3656                     ZUE SA       1.15%          264652.0     2.39 mln
# 3657         TFI BNP Paribas SA       0.77%          177171.0     1.60 mln
# 3658                    DFE PKO       0.22%           49763.0      450 tys
# 3659                 TFI PKO SA       0.16%           37294.0      337 tys
#
#      ticker
# 0       06N
# 1       11B
# 2       11B
# 3       11B
# 4       11B
# ...     ...
# 3655    ZUE
# 3656    ZUE
# 3657    ZUE
# 3658    ZUE
# 3659    ZUE
#
# [3660 rows x 5 columns]

# %%
df_shareholder["Suffix"] = df_shareholder["Market_value"].str[-4:].str.strip()
df_shareholder["Market_value_numeric"] = df_shareholder["Market_value"].str[:-4].str.strip()
df_shareholder["Market_value_numeric"] = df_shareholder["Market_value_numeric"].astype(float)

multipliers = {
    "tys": 1_000,
    "mln": 1_000_000,
    "mld": 1_000_000_000
}

df_shareholder["Market_value"] = df_shareholder["Market_value_numeric"] * df_shareholder["Suffix"].map(multipliers)
df_shareholder = df_shareholder.drop(["Suffix", "Market_value_numeric"], axis=1)
df_shareholder['ticker'] = [i + ".WA" for i in df_shareholder['ticker'].to_list()]
df_shareholder
# Out:
#                     Shareholder Ownership_%  Number_of_shares  Market_value  \
# 0         RG Ventures Sp. z o.o      24.46%         3405807.0    10400000.0
# 1           Grzegorz Miechowski       6.97%          168413.0    47400000.0
# 2               TFI Esaliens SA       6.51%          157257.0    44300000.0
# 3     OFE Nationale-Nederlanden       5.69%          137648.0    38800000.0
# 4            Przemysław Marszał       4.96%          120003.0    33800000.0
# ...                         ...         ...               ...           ...
# 3655               OFE Generali       6.35%         1461659.0    13200000.0
# 3656                     ZUE SA       1.15%          264652.0     2390000.0
# 3657         TFI BNP Paribas SA       0.77%          177171.0     1600000.0
# 3658                    DFE PKO       0.22%           49763.0      450000.0
# 3659                 TFI PKO SA       0.16%           37294.0      337000.0
#
#       ticker
# 0     06N.WA
# 1     11B.WA
# 2     11B.WA
# 3     11B.WA
# 4     11B.WA
# ...      ...
# 3655  ZUE.WA
# 3656  ZUE.WA
# 3657  ZUE.WA
# 3658  ZUE.WA
# 3659  ZUE.WA
#
# [3660 rows x 5 columns]

# %%
df_shareholder_merged = pd.merge(df_shareholder, df_financials[['ticker', 'longName']], on="ticker", how="left")
df_shareholder_merged
# Out:
#                     Shareholder Ownership_%  Number_of_shares  Market_value  \
# 0         RG Ventures Sp. z o.o      24.46%         3405807.0    10400000.0
# 1           Grzegorz Miechowski       6.97%          168413.0    47400000.0
# 2               TFI Esaliens SA       6.51%          157257.0    44300000.0
# 3     OFE Nationale-Nederlanden       5.69%          137648.0    38800000.0
# 4            Przemysław Marszał       4.96%          120003.0    33800000.0
# ...                         ...         ...               ...           ...
# 3655               OFE Generali       6.35%         1461659.0    13200000.0
# 3656                     ZUE SA       1.15%          264652.0     2390000.0
# 3657         TFI BNP Paribas SA       0.77%          177171.0     1600000.0
# 3658                    DFE PKO       0.22%           49763.0      450000.0
# 3659                 TFI PKO SA       0.16%           37294.0      337000.0
#
#       ticker             longName
# 0     06N.WA   Magna Polonia S.A.
# 1     11B.WA  11 bit studios S.A.
# 2     11B.WA  11 bit studios S.A.
# 3     11B.WA  11 bit studios S.A.
# 4     11B.WA  11 bit studios S.A.
# ...      ...                  ...
# 3655  ZUE.WA             ZUE S.A.
# 3656  ZUE.WA             ZUE S.A.
# 3657  ZUE.WA             ZUE S.A.
# 3658  ZUE.WA             ZUE S.A.
# 3659  ZUE.WA             ZUE S.A.
#
# [3660 rows x 6 columns]

# %%
df_shareholder_merged.to_csv("/content/drive/MyDrive/Projects/network-analysis/shareholder_final.csv", index=False)

# %% [markdown]
# #Transforming financial data
#
# ## Finding missing values and updating them

# %%
df_financials
# Out:
#                                        longName shortName  ticker  \
# 0                            Magna Polonia S.A.   06MAGNA  06N.WA
# 1                           11 bit studios S.A.     11BIT  11B.WA
# 2                                     Atal S.A.      ATAL  1AT.WA
# 3                                 3R Games S.A.   3RGAMES  3RG.WA
# 4                                     Alta S.A.      ALTA  AAT.WA
# ..                                          ...       ...     ...
# 316                            Zabka Group S.A.     ZABKA  ZAB.WA
# 317                                   ZE PAK SA     ZEPAK  ZEP.WA
# 318                                  Zamet S.A.     ZAMET  ZMT.WA
# 319  Zaklad Budowy Maszyn ZREMB - Chojnice S.A.     ZREMB  ZRE.WA
# 320                                    ZUE S.A.       ZUE  ZUE.WA
#
#                      sector                                 industry  \
# 0        Financial Services                         Asset Management
# 1    Communication Services           Electronic Gaming & Multimedia
# 2               Real Estate                Real Estate - Development
# 3         Consumer Cyclical                          Internet Retail
# 4        Financial Services                         Asset Management
# ..                      ...                                      ...
# 316                     NaN                                      NaN
# 317               Utilities  Utilities - Independent Power Producers
# 318         Basic Materials                                    Steel
# 319         Basic Materials                                    Steel
# 320             Industrials                Infrastructure Operations
#
#      returnOnEquity  returnOnAssets  p_to_book  debt_to_eq   beta
# 0           0.02317        -0.02091   0.416608       3.903  1.271
# 1          -0.01708         0.00374   2.826666       2.837  0.016
# 2           0.24631         0.07228   1.475206      45.574  0.749
# 3           0.05697         0.03426   1.133333         NaN -0.148
# 4           0.07428        -0.01463   0.165628         NaN  0.321
# ..              ...             ...        ...         ...    ...
# 316             NaN             NaN        NaN         NaN    NaN
# 317         0.51357         0.10823   0.405429       1.618  0.011
# 318         0.01262        -0.02431   0.898613      15.890  0.159
# 319         0.04489         0.02221   2.762022      26.003  0.131
# 320         0.12406         0.03250   0.905489      51.911  0.516
#
# [321 rows x 10 columns]

# %%
df_fin_nans = pd.isna(df_financials).any(axis=1)
df_records_with_nans = df_financials[df_fin_nans]
df_records_with_nans
# Out:
#                 longName  shortName  ticker                  sector  \
# 3          3R Games S.A.    3RGAMES  3RG.WA       Consumer Cyclical
# 4              Alta S.A.       ALTA  AAT.WA      Financial Services
# 5                AB S.A.       ABPL  ABE.WA              Technology
# 7      AC Spólka Akcyjna  ACAUTOGAZ  ACG.WA       Consumer Cyclical
# 9            Action S.A.     ACTION  ACT.WA              Technology
# ..                   ...        ...     ...                     ...
# 291     UniCredit S.p.A.  UNICREDIT  UCG.WA      Financial Services
# 292  Ultimate Games S.A.   ULTGAMES  ULG.WA  Communication Services
# 308                  NaN   WOODPCKR  WPR.WA              Technology
# 313             XTB S.A.        XTB  XTB.WA      Financial Services
# 316     Zabka Group S.A.      ZABKA  ZAB.WA                     NaN
#
#                                 industry  returnOnEquity  returnOnAssets  \
# 3                        Internet Retail         0.05697         0.03426
# 4                       Asset Management         0.07428        -0.01463
# 5    Electronics & Computer Distribution             NaN             NaN
# 7                             Auto Parts         0.20383         0.08560
# 9                      Computer Hardware             NaN             NaN
# ..                                   ...             ...             ...
# 291                     Banks - Regional         0.16710         0.01300
# 292       Electronic Gaming & Multimedia        -0.15284         0.05017
# 308            Software - Infrastructure             NaN             NaN
# 313                      Capital Markets             NaN             NaN
# 316                                  NaN             NaN             NaN
#
#      p_to_book  debt_to_eq   beta
# 3     1.133333         NaN -0.148
# 4     0.165628         NaN  0.321
# 5     1.018664      22.565  0.840
# 7     1.710929         NaN  0.424
# 9     0.609101       0.735  1.088
# ..         ...         ...    ...
# 291   4.733298         NaN  1.425
# 292   2.071075         NaN  1.035
# 308        NaN         NaN    NaN
# 313   5.217200      11.276  0.872
# 316        NaN         NaN    NaN
#
# [73 rows x 10 columns]

# %%
industry_medians = df_financials.groupby('industry').agg({
    'returnOnEquity': 'median',
    'returnOnAssets': 'median',
    'p_to_book': 'median',
    'debt_to_eq': 'median',
    'beta':'median'
})

sector_medians = df_financials.groupby('sector').agg({
    'returnOnEquity': 'median',
    'returnOnAssets': 'median',
    'p_to_book': 'median',
    'debt_to_eq': 'median',
    'beta':'median'
})

# %%
def fill_missing_values(row):
  for column in ['returnOnEquity', 'returnOnAssets', 'p_to_book', 'debt_to_eq', 'beta']:
    if pd.isna(row[column]):
      industry = row['industry']
      sector = row['sector']

      if industry in industry_medians.index and not pd.isna(industry_medians.loc[industry, column]):
        row[column] = industry_medians.loc[industry, column]

      elif sector in sector_medians.index and not pd.isna(sector_medians.loc[sector, column]):
        row[column] = sector_medians.loc[sector, column]
  return row

df_financials = df_financials.apply(fill_missing_values, axis=1)

# %%
df_fin_nans = pd.isna(df_financials).any(axis=1)
df_records_with_nans = df_financials[df_fin_nans]
df_records_with_nans
# Out:
#              longName shortName  ticker                  sector  \
# 142               NaN       JRH  JRH.WA      Financial Services
# 239               NaN      PTWP  PTW.WA  Communication Services
# 249               NaN    RENDER  RND.WA  Communication Services
# 308               NaN  WOODPCKR  WPR.WA              Technology
# 316  Zabka Group S.A.     ZABKA  ZAB.WA                     NaN
#
#                            industry  returnOnEquity  returnOnAssets  \
# 142                Asset Management        -0.55532        -0.25859
# 239                      Publishing         0.13190         0.06409
# 249  Electronic Gaming & Multimedia         0.27131         0.20925
# 308       Software - Infrastructure         0.01090         0.01221
# 316                             NaN             NaN             NaN
#
#      p_to_book  debt_to_eq    beta
# 142   1.837110      8.3155 -0.1120
# 239   3.083794      0.8890  0.2780
# 249   3.088508      3.4695  0.4290
# 308   5.629378     39.1670  0.8435
# 316        NaN         NaN     NaN
